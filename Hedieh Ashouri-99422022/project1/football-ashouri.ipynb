# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from scipy import stats 
import urllib 
import os
import datetime

# %%
# csv file read/load
df = pd.read_csv('D:\\results.csv')
df.shape
# Out:
# (42082, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42082 entries, 0 to 42081
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        42082 non-null  object
#  1   home_team   42082 non-null  object
#  2   away_team   42082 non-null  object
#  3   home_score  42082 non-null  int64
#  4   away_score  42082 non-null  int64
#  5   tournament  42082 non-null  object
#  6   city        42082 non-null  object
#  7   country     42082 non-null  object
#  8   neutral     42082 non-null  bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.6+ MB

# %%
print(' the field name of data:',df.columns)
# Out:
#  the field name of data: Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
# data output
df
# Out:
#              date      home_team        away_team  home_score  away_score  \
# 0      1872-11-30       Scotland          England           0           0
# 1      1873-03-08        England         Scotland           4           2
# 2      1874-03-07       Scotland          England           2           1
# 3      1875-03-06        England         Scotland           2           2
# 4      1876-03-04       Scotland          England           3           0
# ...           ...            ...              ...         ...         ...
# 42077  2021-03-31        Andorra          Hungary           1           4
# 42078  2021-03-31     San Marino          Albania           0           2
# 42079  2021-03-31        Armenia          Romania           3           2
# 42080  2021-03-31        Germany  North Macedonia           1           2
# 42081  2021-03-31  Liechtenstein          Iceland           1           4
#
#                          tournament              city        country  neutral
# 0                          Friendly           Glasgow       Scotland    False
# 1                          Friendly            London        England    False
# 2                          Friendly           Glasgow       Scotland    False
# 3                          Friendly            London        England    False
# 4                          Friendly           Glasgow       Scotland    False
# ...                             ...               ...            ...      ...
# 42077  FIFA World Cup qualification  Andorra la Vella        Andorra    False
# 42078  FIFA World Cup qualification        Serravalle     San Marino    False
# 42079  FIFA World Cup qualification           Yerevan        Armenia    False
# 42080  FIFA World Cup qualification          Duisburg        Germany    False
# 42081  FIFA World Cup qualification             Vaduz  Liechtenstein    False
#
# [42082 rows x 9 columns]

# %%
df.dtypes
# Out:
# date          object
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# neutral         bool
# dtype: object

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.describe()
# Out:
#          home_score    away_score
# count  42082.000000  42082.000000
# mean       1.743691      1.186541
# std        1.752459      1.403957
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df["Year"]=pd.to_datetime(df['date']).dt.year
df["Month"]=pd.to_datetime(df['date']).dt.month
df=df.drop(columns=['date'], axis=1)
df.head()
# Out:
#   home_team away_team  home_score  away_score tournament     city   country  \
# 0  Scotland   England           0           0   Friendly  Glasgow  Scotland
# 1   England  Scotland           4           2   Friendly   London   England
# 2  Scotland   England           2           1   Friendly  Glasgow  Scotland
# 3   England  Scotland           2           2   Friendly   London   England
# 4  Scotland   England           3           0   Friendly  Glasgow  Scotland
#
#    neutral  Year  Month
# 0    False  1872     11
# 1    False  1873      3
# 2    False  1874      3
# 3    False  1875      3
# 4    False  1876      3

# %%
df['total_score']=df['home_score']+df['away_score']
df.head()
# Out:
#   home_team away_team  home_score  away_score tournament     city   country  \
# 0  Scotland   England           0           0   Friendly  Glasgow  Scotland
# 1   England  Scotland           4           2   Friendly   London   England
# 2  Scotland   England           2           1   Friendly  Glasgow  Scotland
# 3   England  Scotland           2           2   Friendly   London   England
# 4  Scotland   England           3           0   Friendly  Glasgow  Scotland
#
#    neutral  Year  Month  total_score
# 0    False  1872     11            0
# 1    False  1873      3            6
# 2    False  1874      3            3
# 3    False  1875      3            4
# 4    False  1876      3            3

# %%
con=[(df['home_score']==df['away_score']),(df['home_score']>df['away_score']),(df['home_score']<df['away_score'])]
val=[0,1,2]
val2=['no_win',df['home_team'],df['away_team']]
df['result']=np.select(con,val)
df['who_win']=np.select(con,val2)
df.head()
# Out:
#   home_team away_team  home_score  away_score tournament     city   country  \
# 0  Scotland   England           0           0   Friendly  Glasgow  Scotland
# 1   England  Scotland           4           2   Friendly   London   England
# 2  Scotland   England           2           1   Friendly  Glasgow  Scotland
# 3   England  Scotland           2           2   Friendly   London   England
# 4  Scotland   England           3           0   Friendly  Glasgow  Scotland
#
#    neutral  Year  Month  total_score  result   who_win
# 0    False  1872     11            0       0    no_win
# 1    False  1873      3            6       1   England
# 2    False  1874      3            3       1  Scotland
# 3    False  1875      3            4       0    no_win
# 4    False  1876      3            3       1  Scotland

# %%
# teams with the most goals
bestteam=df.groupby('who_win').sum()
bestteam=bestteam[['home_score','away_score','total_score']].sort_values(by=['total_score'],ascending=False)
bestteam=bestteam.drop(['no_win'])
bestteam.head(10)
# Out:
#              home_score  away_score  total_score
# who_win
# Brazil             1366         836         2202
# England            1163        1036         2199
# Germany            1233         886         2119
# Sweden             1084         806         1890
# Argentina          1158         622         1780
# Hungary            1030         739         1769
# Netherlands         914         598         1512
# Mexico              945         483         1428
# France              902         524         1426
# South Korea         882         512         1394

# %%
# most winning teams
bestteam2=df.groupby('who_win').count()
bestteam2=bestteam2[['result']].sort_values(by=['result'],ascending=False)
bestteam2=bestteam2.drop(['no_win'])

bestteam2.head(10)
# Out:
#              result
# who_win
# Brazil          629
# England         580
# Germany         560
# Argentina       529
# Sweden          506
# South Korea     455
# Mexico          443
# Hungary         442
# Italy           431
# France          425

# %%
# merge most winning teams and gols
bestteam3=pd.merge(bestteam,bestteam2, how='inner', on='who_win')
bestteam3['teams']=bestteam3.index
bestteam3.head()
# Out:
#            home_score  away_score  total_score  result      teams
# who_win
# Brazil           1366         836         2202     629     Brazil
# England          1163        1036         2199     580    England
# Germany          1233         886         2119     560    Germany
# Sweden           1084         806         1890     506     Sweden
# Argentina        1158         622         1780     529  Argentina

# %%
#the number of matches they played
match=df.groupby('home_team').count()+df.groupby('away_team').count()
match=match[['city']].sort_values(by=['city'],ascending=False)
match=match.rename(columns = {'city':'play_count'})
match['teams']=match.index
match.head()
# Out:
#            play_count      teams
# Sweden         1030.0     Sweden
# England        1020.0    England
# Brazil          985.0     Brazil
# Argentina       984.0  Argentina
# Germany         961.0    Germany

# %%
#merge the number of matches they played and winner
bestteam=pd.merge(match,bestteam3,how='inner', on='teams')
bestteam['win_per_game']=bestteam4['result']/bestteam4['play_count']
bestteam['goal_per_game']=bestteam4['total_score']/bestteam4['play_count']
bestteam=bestteam4[['teams', 'play_count', 'total_score', 'result', 'win_per_game', 'goal_per_game']]
bestteam.head()
# Out:
#                   teams  play_count  total_score  result  win_per_game  \
# 282           Yorkshire         7.0           33       5      0.714286
# 228             Padania        43.0          115      29      0.674419
# 200              Jersey        82.0          186      55      0.670732
# 290  Parishes of Jersey         3.0           14       2      0.666667
# 273      County of Nice         9.0           21       6      0.666667
#
#      goal_per_game
# 282       4.714286
# 228       2.674419
# 200       2.268293
# 290       4.666667
# 273       2.333333

# %%
bestteam=bestteam.sort_values(by=['win_per_game'],ascending=False)
bestteam.head(10)
# Out:
#                   teams  play_count  total_score  result  win_per_game  \
# 282           Yorkshire         7.0           33       5      0.714286
# 228             Padania        43.0          115      29      0.674419
# 200              Jersey        82.0          186      55      0.670732
# 290  Parishes of Jersey         3.0           14       2      0.666667
# 273      County of Nice         9.0           21       6      0.666667
# 212      Basque Country        57.0          170      37      0.649123
# 2                Brazil       985.0         2202     629      0.638579
# 262           Andalusia        13.0           26       8      0.615385
# 253              Rhodes        18.0           32      11      0.611111
# 289              Crimea         5.0            9       3      0.600000
#
#      goal_per_game
# 282       4.714286
# 228       2.674419
# 200       2.268293
# 290       4.666667
# 273       2.333333
# 212       2.982456
# 2         2.235533
# 262       2.000000
# 253       1.777778
# 289       1.800000

# %%
bestteam.plot(kind='scatter',x='play_count',y='win_per_game',color='r',alpha=0.5)
plt.xlabel('play_count')
plt.ylabel('win_per_game')
plt.title('play_count and win_per_game Scatter Plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bestteam1=bestteam[(bestteam['win_per_game']>0,4) and (bestteam4['play_count']>800)]
bestteam1.head()
# Out:
# <ipython-input-98-7d1a4e215c46>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bestteam1=bestteam[(bestteam['win_per_game']>0,4) and (bestteam4['play_count']>800)]
#         teams  play_count  total_score  result  win_per_game  goal_per_game
# 2      Brazil       985.0         2202     629      0.638579       2.235533
# 4     Germany       961.0         2119     560      0.582726       2.204995
# 1     England      1020.0         2199     580      0.568627       2.155882
# 3   Argentina       984.0         1780     529      0.537602       1.808943
# 12      Italy       812.0         1321     431      0.530788       1.626847

# %%
bestteam1.plot(kind='scatter',x='play_count',y='win_per_game',color='r',alpha=0.5,label='teams')
plt.xlabel('play_count')
plt.ylabel('win_per_game')
plt.title('play_count and win_per_game Scatter Plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(1, figsize=(10, 6))
fig.suptitle('play_count and win_per_game Scatter Plot')

# Plot the scatter points
x=bestteam1['play_count']
y=bestteam1['win_per_game']
labels=bestteam1['teams']
ax.scatter(x,y,
           color="blue",  # Color of the dots
           s=100,         # Size of the dots
           alpha=0.5,     # Alpha of the dots
           linewidths=1)  # Size of edge around the dots

# Add the participant names as text labels for each point
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

plt.show()

# %%
df.head()
# Out:
#   home_team away_team  home_score  away_score tournament     city   country  \
# 0  Scotland   England           0           0   Friendly  Glasgow  Scotland
# 1   England  Scotland           4           2   Friendly   London   England
# 2  Scotland   England           2           1   Friendly  Glasgow  Scotland
# 3   England  Scotland           2           2   Friendly   London   England
# 4  Scotland   England           3           0   Friendly  Glasgow  Scotland
#
#    neutral  Year  Month  total_score  result   who_win
# 0    False  1872     11            0       0    no_win
# 1    False  1873      3            6       1   England
# 2    False  1874      3            3       1  Scotland
# 3    False  1875      3            4       0    no_win
# 4    False  1876      3            3       1  Scotland

# %%
teams=df[['Year','who_win']]
teams.head()
# Out:
#    Year   who_win
# 0  1872    no_win
# 1  1873   England
# 2  1874  Scotland
# 3  1875    no_win
# 4  1876  Scotland

# %%
def re_find(who_win):
    if "no_win" not in who_win.lower():
        return True
    return False

teams2=teams[teams['who_win'].apply(re_find)]

teams2.head()
# Out:
#    Year   who_win
# 1  1873   England
# 2  1874  Scotland
# 4  1876  Scotland
# 5  1876  Scotland
# 6  1877  Scotland

# %%
list1=[]
list2=[]
list3=[]
b=teams2['Year'].count()
for i in range(0,b):
    list1.append(teams2['Year'].iloc[i])
    list2.append(teams2['who_win'].iloc[i])
    a=str(teams2['Year'].iloc[i])+teams2['who_win'].iloc[i]
    list3.append(a)
    
list_label = ["Year","who_win","Year_who_win"] 
list_col = [list1,list2,list3]       
zipped = zip(list_label,list_col) 
data_dict = dict(zipped)  

teams3 = pd.DataFrame(data_dict)
teams3.head()
# Out:
#    Year   who_win  Year_who_win
# 0  1873   England   1873England
# 1  1874  Scotland  1874Scotland
# 2  1876  Scotland  1876Scotland
# 3  1876  Scotland  1876Scotland
# 4  1877  Scotland  1877Scotland

# %%
teams4=teams3.groupby('Year_who_win').count()
team4=teams4[['who_win']].sort_values(by=['who_win'], ascending=False)
teams4.head()
# Out:
#               Year  who_win
# Year_who_win
# 1873England      1        1
# 1874Scotland     1        1
# 1876Scotland     2        2
# 1877Scotland     2        2
# 1878Scotland     2        2

# %%
df.head()
# Out:
#   home_team away_team  home_score  away_score tournament     city   country  \
# 0  Scotland   England           0           0   Friendly  Glasgow  Scotland
# 1   England  Scotland           4           2   Friendly   London   England
# 2  Scotland   England           2           1   Friendly  Glasgow  Scotland
# 3   England  Scotland           2           2   Friendly   London   England
# 4  Scotland   England           3           0   Friendly  Glasgow  Scotland
#
#    neutral  Year  Month  total_score  result   who_win
# 0    False  1872     11            0       0    no_win
# 1    False  1873      3            6       1   England
# 2    False  1874      3            3       1  Scotland
# 3    False  1875      3            4       0    no_win
# 4    False  1876      3            3       1  Scotland

# %%
con=[(df['home_team']==df['who_win']),(df['away_team']==df['who_win'])]
val=['home_win','away_win']
val2=[1,1]
df['home_away_win']=np.select(con,val)
df['home_away_win2']=np.select(con,val2)
df.head()
# Out:
#   home_team away_team  home_score  away_score tournament     city   country  \
# 0  Scotland   England           0           0   Friendly  Glasgow  Scotland
# 1   England  Scotland           4           2   Friendly   London   England
# 2  Scotland   England           2           1   Friendly  Glasgow  Scotland
# 3   England  Scotland           2           2   Friendly   London   England
# 4  Scotland   England           3           0   Friendly  Glasgow  Scotland
#
#    neutral  Year  Month  total_score  result   who_win home_away_win  \
# 0    False  1872     11            0       0    no_win             0
# 1    False  1873      3            6       1   England      home_win
# 2    False  1874      3            3       1  Scotland      home_win
# 3    False  1875      3            4       0    no_win             0
# 4    False  1876      3            3       1  Scotland      home_win
#
#    home_away_win2
# 0               0
# 1               1
# 2               1
# 3               0
# 4               1

# %%
#home advantage?
data1=df.groupby('home_away_win').count()
data1[['who_win']]
# Out:
#                who_win
# home_away_win
# 0                 9700
# away_win         11924
# home_win         20458

# %%
my_colors = ['yellow','red','green']
my_explode = (0, 0.1, 0)
plt.pie(data1['who_win'], labels=data1.index, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.title('Which teams are advantageous')
plt.axis('equal')
plt.show()

# %%
df_c=df[['Year','country']]
df_c = df_c.drop_duplicates()
df_c1=df_c.groupby('Year').count()

plt.plot(df_c1.index, df_c1['country'], color='red', marker='o')
plt.title('Year and number of country ', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('country', fontsize=14)
plt.grid(True)
plt.show()

# %%
data_c = df.drop(df[df.country == df.home_team].index)
list1=[]
list2=[]
b=len(data_c.index)
for i in range(0,b):
    list1.append(data_c['country'].iloc[i])
    list2.append(1)

list_label = ["Country","Num"] 
list_col = [list1,list2]       
zipped = zip(list_label,list_col) 
data_dict = dict(zipped) 

data_c3 = pd.DataFrame(data_dict) 
data_c4=data_c3.groupby('Country').count()
data_c5=data_c4[['Num']]
data_c6=data_c5.sort_values(by=['Num'], ascending=False)
data_c6.head()
# Out:
#                       Num
# Country
# United States         772
# Malaysia              428
# France                375
# South Africa          284
# United Arab Emirates  276

# %%
df_corr = df.corr()
sns.heatmap(df_corr,cmap='plasma_r', lw = 1, annot = True)
# Out:
# <AxesSubplot:>

# %%
df['tournament'].value_counts()
# Out:
# Friendly                                17189
# FIFA World Cup qualification             7363
# UEFA Euro qualification                  2582
# African Cup of Nations qualification     1719
# FIFA World Cup                            900
#                                         ...
# World Unity Cup                             4
# Dragon Cup                                  4
# AFF Championship qualification              2
# Atlantic Heritage Cup                       2
# Copa América qualification                  2
# Name: tournament, Length: 112, dtype: int64

# %%
sns.barplot(x=df['tournament'].value_counts().index[:20],y=df['tournament'].value_counts().values[:20])
plt.xticks(rotation=90)
plt.show()

# %%
df['tournament'].unique()
# Out:
# array(['Friendly', 'British Championship', 'Copa Lipton', 'Copa Newton',
#        'Copa Premio Honor Argentino', 'Copa Premio Honor Uruguayo',
#        'Copa Roca', 'Copa América', 'Copa Chevallier Boutell',
#        'Nordic Championship', 'International Cup', 'Baltic Cup',
#        'Balkan Cup', 'FIFA World Cup', 'Copa Rio Branco',
#        'FIFA World Cup qualification', 'CCCF Championship',
#        'NAFU Championship', 'Copa Oswaldo Cruz',
#        'Pan American Championship', 'Copa del Pacífico',
#        "Copa Bernardo O'Higgins", 'AFC Asian Cup qualification',
#        'Atlantic Cup', 'AFC Asian Cup', 'African Cup of Nations',
#        'Copa Paz del Chaco', 'Merdeka Tournament',
#        'UEFA Euro qualification', 'UEFA Euro',
#        'Windward Islands Tournament',
#        'African Cup of Nations qualification', 'Vietnam Independence Cup',
#        'Copa Carlos Dittborn', 'CONCACAF Championship',
#        'Copa Juan Pinto Durán', 'UAFA Cup', 'South Pacific Games',
#        'CONCACAF Championship qualification', 'Copa Artigas', 'GaNEFo',
#        "King's Cup", 'Gulf Cup', 'Indonesia Tournament', 'Korea Cup',
#        'Brazil Independence Cup', 'Copa Ramón Castilla',
#        'Oceania Nations Cup', 'CECAFA Cup', 'Copa Félix Bogado',
#        'Kirin Cup', 'CFU Caribbean Cup qualification',
#        'CFU Caribbean Cup', 'Amílcar Cabral Cup', 'Mundialito',
#        'West African Cup', 'Nehru Cup', 'Merlion Cup', 'UDEAC Cup',
#        'Rous Cup', 'Lunar New Year Cup', 'Tournoi de France',
#        'Malta International Tournament', 'Island Games', 'Dynasty Cup',
#        'UNCAF Cup', 'Gold Cup', 'USA Cup',
#        'Jordan International Tournament', 'Confederations Cup',
#        'United Arab Emirates Friendship Tournament',
#        'Oceania Nations Cup qualification', 'Simba Tournament',
#        'SAFF Cup', 'AFF Championship', 'King Hassan II Tournament',
#        'Cyprus International Tournament', 'Dunhill Cup', 'COSAFA Cup',
#        'Gold Cup qualification', 'SKN Football Festival', 'UNIFFAC Cup',
#        'WAFF Championship', 'Millennium Cup', "Prime Minister's Cup",
#        'EAFF Championship', 'AFC Challenge Cup', 'FIFI Wild Cup',
#        'ELF Cup', 'Viva World Cup', 'UAFA Cup qualification',
#        'AFC Challenge Cup qualification', 'African Nations Championship',
#        'VFF Cup', 'Dragon Cup', 'ABCS Tournament',
#        'Nile Basin Tournament', 'Nations Cup', 'Pacific Games', 'OSN Cup',
#        'CONIFA World Football Cup', 'CONIFA European Football Cup',
#        'Copa América qualification', 'World Unity Cup',
#        'Intercontinental Cup', 'AFF Championship qualification',
#        'UEFA Nations League', 'CONCACAF Nations League qualification',
#        'African Nations Championship qualification',
#        'Atlantic Heritage Cup', 'Inter Games Football Tournament',
#        'CONCACAF Nations League'], dtype=object)

# %%
LT=len(df['tournament'].unique())
LT
# Out:
# 112

# %%
tournament=df['tournament'].value_counts()
names=tournament.index
values=tournament.values

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=names[:10],y=values[:10])
plt.xticks(rotation=90)
plt.ylabel('Values')
plt.xlabel('Tournament')
plt.title('Tournament vs Values')
plt.show()

# %%
sns.pairplot(df.iloc[:,2:5])
plt.show()

# %%
sns.violinplot(x=df['home_score'][:50],y=df['away_score'][:50])
plt.show()

# %%
sns.violinplot(x="home_score", y="away_score", hue="neutral",data=df)
sns.despine(left=True)
plt.show()

# %%
sns.scatterplot(y="home_score", x="away_score",
                hue="neutral",data=df)
plt.show()

# %%
veri=df[df['tournament']=='FIFA World Cup'].tail(56)
veri
# Out:
#           home_team     away_team  home_score  away_score      tournament  \
# 39914    Costa Rica        Serbia           0           1  FIFA World Cup
# 39915       Germany        Mexico           0           1  FIFA World Cup
# 39916        Brazil   Switzerland           1           1  FIFA World Cup
# 39917        Sweden   South Korea           1           0  FIFA World Cup
# 39918       Belgium        Panama           3           0  FIFA World Cup
# 39919       Tunisia       England           1           2  FIFA World Cup
# 39920      Colombia         Japan           1           2  FIFA World Cup
# 39921        Poland       Senegal           1           2  FIFA World Cup
# 39922        Russia         Egypt           3           1  FIFA World Cup
# 39923      Portugal       Morocco           1           0  FIFA World Cup
# 39924       Uruguay  Saudi Arabia           1           0  FIFA World Cup
# 39925          Iran         Spain           0           1  FIFA World Cup
# 39926       Denmark     Australia           1           1  FIFA World Cup
# 39927        France          Peru           1           0  FIFA World Cup
# 39928     Argentina       Croatia           0           3  FIFA World Cup
# 39929        Brazil    Costa Rica           2           0  FIFA World Cup
# 39930       Nigeria       Iceland           2           0  FIFA World Cup
# 39931        Serbia   Switzerland           1           2  FIFA World Cup
# 39932       Belgium       Tunisia           5           2  FIFA World Cup
# 39933   South Korea        Mexico           1           2  FIFA World Cup
# 39934       Germany        Sweden           2           1  FIFA World Cup
# 39935       England        Panama           6           1  FIFA World Cup
# 39936         Japan       Senegal           2           2  FIFA World Cup
# 39937        Poland      Colombia           0           3  FIFA World Cup
# 39938        Russia       Uruguay           0           3  FIFA World Cup
# 39939  Saudi Arabia         Egypt           2           1  FIFA World Cup
# 39940         Spain       Morocco           2           2  FIFA World Cup
# 39941          Iran      Portugal           1           1  FIFA World Cup
# 39942     Australia          Peru           0           2  FIFA World Cup
# 39943       Denmark        France           0           0  FIFA World Cup
# 39944       Nigeria     Argentina           1           2  FIFA World Cup
# 39945       Iceland       Croatia           1           2  FIFA World Cup
# 39946   South Korea       Germany           2           0  FIFA World Cup
# 39947        Mexico        Sweden           0           3  FIFA World Cup
# 39948        Serbia        Brazil           0           2  FIFA World Cup
# 39949   Switzerland    Costa Rica           2           2  FIFA World Cup
# 39950         Japan        Poland           0           1  FIFA World Cup
# 39951       Senegal      Colombia           0           1  FIFA World Cup
# 39952        Panama       Tunisia           1           2  FIFA World Cup
# 39953       England       Belgium           0           1  FIFA World Cup
# 39954        France     Argentina           4           3  FIFA World Cup
# 39955       Uruguay      Portugal           2           1  FIFA World Cup
# 39956        Russia         Spain           1           1  FIFA World Cup
# 39957       Croatia       Denmark           1           1  FIFA World Cup
# 39958        Brazil        Mexico           2           0  FIFA World Cup
# 39959       Belgium         Japan           3           2  FIFA World Cup
# 39960        Sweden   Switzerland           1           0  FIFA World Cup
# 39961      Colombia       England           1           1  FIFA World Cup
# 39963       Uruguay        France           0           2  FIFA World Cup
# 39964        Brazil       Belgium           1           2  FIFA World Cup
# 39965        Sweden       England           0           2  FIFA World Cup
# 39966        Russia       Croatia           2           2  FIFA World Cup
# 39967        France       Belgium           1           0  FIFA World Cup
# 39968       Croatia       England           2           1  FIFA World Cup
# 39969       Belgium       England           2           0  FIFA World Cup
# 39970        France       Croatia           4           2  FIFA World Cup
#
#                   city country  neutral  Year  Month  total_score  result  \
# 39914           Samara  Russia     True  2018      6            1       2
# 39915           Moscow  Russia     True  2018      6            1       2
# 39916    Rostov-on-Don  Russia     True  2018      6            2       0
# 39917  Nizhny Novgorod  Russia     True  2018      6            1       1
# 39918            Sochi  Russia     True  2018      6            3       1
# 39919        Volgograd  Russia     True  2018      6            3       2
# 39920          Saransk  Russia     True  2018      6            3       2
# 39921           Moscow  Russia     True  2018      6            3       2
# 39922   St. Petersburg  Russia    False  2018      6            4       1
# 39923           Moscow  Russia     True  2018      6            1       1
# 39924    Rostov-on-Don  Russia     True  2018      6            1       1
# 39925            Kazan  Russia     True  2018      6            1       2
# 39926           Samara  Russia     True  2018      6            2       0
# 39927     Ekaterinburg  Russia     True  2018      6            1       1
# 39928  Nizhny Novgorod  Russia     True  2018      6            3       2
# 39929   St. Petersburg  Russia     True  2018      6            2       1
# 39930        Volgograd  Russia     True  2018      6            2       1
# 39931      Kaliningrad  Russia     True  2018      6            3       2
# 39932           Moscow  Russia     True  2018      6            7       1
# 39933    Rostov-on-Don  Russia     True  2018      6            3       2
# 39934            Sochi  Russia     True  2018      6            3       1
# 39935  Nizhny Novgorod  Russia     True  2018      6            7       1
# 39936     Ekaterinburg  Russia     True  2018      6            4       0
# 39937            Kazan  Russia     True  2018      6            3       2
# 39938           Samara  Russia    False  2018      6            3       2
# 39939        Volgograd  Russia     True  2018      6            3       1
# 39940      Kaliningrad  Russia     True  2018      6            4       0
# 39941          Saransk  Russia     True  2018      6            2       0
# 39942            Sochi  Russia     True  2018      6            2       2
# 39943           Moscow  Russia     True  2018      6            0       0
# 39944   St. Petersburg  Russia     True  2018      6            3       2
# 39945    Rostov-on-Don  Russia     True  2018      6            3       2
# 39946            Kazan  Russia     True  2018      6            2       1
# 39947     Ekaterinburg  Russia     True  2018      6            3       2
# 39948           Moscow  Russia     True  2018      6            2       2
# 39949  Nizhny Novgorod  Russia     True  2018      6            4       0
# 39950        Volgograd  Russia     True  2018      6            1       2
# 39951           Samara  Russia     True  2018      6            1       2
# 39952          Saransk  Russia     True  2018      6            3       2
# 39953      Kaliningrad  Russia     True  2018      6            1       2
# 39954            Kazan  Russia     True  2018      6            7       1
# 39955            Sochi  Russia     True  2018      6            3       1
# 39956           Moscow  Russia    False  2018      7            2       0
# 39957  Nizhny Novgorod  Russia     True  2018      7            2       0
# 39958           Samara  Russia     True  2018      7            2       1
# 39959    Rostov-on-Don  Russia     True  2018      7            5       1
# 39960   St. Petersburg  Russia     True  2018      7            1       1
# 39961           Moscow  Russia     True  2018      7            2       0
# 39963  Nizhny Novgorod  Russia     True  2018      7            2       2
# 39964            Kazan  Russia     True  2018      7            3       2
# 39965           Samara  Russia     True  2018      7            2       2
# 39966            Sochi  Russia    False  2018      7            4       0
# 39967   St. Petersburg  Russia     True  2018      7            1       1
# 39968           Moscow  Russia     True  2018      7            3       1
# 39969   St. Petersburg  Russia     True  2018      7            2       1
# 39970           Moscow  Russia     True  2018      7            6       1
#
#             who_win home_away_win  home_away_win2
# 39914        Serbia      away_win               1
# 39915        Mexico      away_win               1
# 39916        no_win             0               0
# 39917        Sweden      home_win               1
# 39918       Belgium      home_win               1
# 39919       England      away_win               1
# 39920         Japan      away_win               1
# 39921       Senegal      away_win               1
# 39922        Russia      home_win               1
# 39923      Portugal      home_win               1
# 39924       Uruguay      home_win               1
# 39925         Spain      away_win               1
# 39926        no_win             0               0
# 39927        France      home_win               1
# 39928       Croatia      away_win               1
# 39929        Brazil      home_win               1
# 39930       Nigeria      home_win               1
# 39931   Switzerland      away_win               1
# 39932       Belgium      home_win               1
# 39933        Mexico      away_win               1
# 39934       Germany      home_win               1
# 39935       England      home_win               1
# 39936        no_win             0               0
# 39937      Colombia      away_win               1
# 39938       Uruguay      away_win               1
# 39939  Saudi Arabia      home_win               1
# 39940        no_win             0               0
# 39941        no_win             0               0
# 39942          Peru      away_win               1
# 39943        no_win             0               0
# 39944     Argentina      away_win               1
# 39945       Croatia      away_win               1
# 39946   South Korea      home_win               1
# 39947        Sweden      away_win               1
# 39948        Brazil      away_win               1
# 39949        no_win             0               0
# 39950        Poland      away_win               1
# 39951      Colombia      away_win               1
# 39952       Tunisia      away_win               1
# 39953       Belgium      away_win               1
# 39954        France      home_win               1
# 39955       Uruguay      home_win               1
# 39956        no_win             0               0
# 39957        no_win             0               0
# 39958        Brazil      home_win               1
# 39959       Belgium      home_win               1
# 39960        Sweden      home_win               1
# 39961        no_win             0               0
# 39963        France      away_win               1
# 39964       Belgium      away_win               1
# 39965       England      away_win               1
# 39966        no_win             0               0
# 39967        France      home_win               1
# 39968       Croatia      home_win               1
# 39969       Belgium      home_win               1
# 39970        France      home_win               1

# %%
veri=df[df['tournament']=='FIFA World Cup'].tail(56)

len(veri['home_team'].unique())
allteam=veri['home_team'].unique()
allteam
# Out:
# array(['Costa Rica', 'Germany', 'Brazil', 'Sweden', 'Belgium', 'Tunisia',
#        'Colombia', 'Poland', 'Russia', 'Portugal', 'Uruguay', 'Iran',
#        'Denmark', 'France', 'Argentina', 'Nigeria', 'Serbia',
#        'South Korea', 'England', 'Japan', 'Saudi Arabia', 'Spain',
#        'Australia', 'Iceland', 'Mexico', 'Switzerland', 'Senegal',
#        'Panama', 'Croatia'], dtype=object)

# %%
away_scores_allteam=[]
home_scores_allteam=[]
for team in allteam:
    toplam=sum(veri[veri['home_team']==team].away_score)
    away_scores_allteam.append(toplam)
    home_scores_allteam.append(sum(veri[veri['home_team']==team].home_score))
    toplam=0

away_scores_allteam
home_scores_allteam
allteam

all_team=pd.DataFrame([allteam,home_scores_allteam,away_scores_allteam])
                       
all_team
# Out:
#            0        1       2       3        4        5         6       7   \
# 0  Costa Rica  Germany  Brazil  Sweden  Belgium  Tunisia  Colombia  Poland
# 1           0        2       6       2       13        1         2       1
# 2           1        2       3       2        4        2         3       5
#
#        8         9   ...     19            20     21         22       23  \
# 0  Russia  Portugal  ...  Japan  Saudi Arabia  Spain  Australia  Iceland
# 1       6         1  ...      2             2      2          0        1
# 2       7         0  ...      3             1      2          2        2
#
#        24           25       26      27       28
# 0  Mexico  Switzerland  Senegal  Panama  Croatia
# 1       0            2        0       1        3
# 2       3            2        1       2        2
#
# [3 rows x 29 columns]

# %%
f,ax1=plt.subplots(figsize=(20,10))
sns.pointplot(x=allteam,y=home_scores_allteam,data=veri,color='lime',alpha=0.8)
sns.pointplot(x=allteam,y=away_scores_allteam,data=veri,color='red',alpha=0.8)
plt.text(30,0.5,'FIFA CUP 2018 HOME SCORE',color='red',fontsize = 10,style = 'italic')
plt.text(30,0.5,'FIFA CUP 2018 AWAY SCORE',color='lime',fontsize = 10,style = 'italic')
plt.xlabel('TEAM',fontsize = 15,color='blue')
plt.xticks(rotation=90)
plt.ylabel('SCORES',fontsize = 15,color='blue')
plt.title('AWAY SCORES VS HOME SCORES',fontsize = 20,color='blue')
plt.grid()

# %%
sns.barplot(x=allteam,y=home_scores_allteam)
plt.title('FIFA CUP 2018 Home Scores',color='b',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=allteam,y=away_scores_allteam)
plt.title('FIFA CUP 2018 Away Scores',color='b',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
tournament = matches['tournament'].value_counts()
tournament = tournament[:10]

plt.figure(figsize = (15,10))
sns.set_style("whitegrid")
ax = sns.barplot(y=tournament.index, x=tournament.values, palette="Reds_r", orient='h')
ax.set_ylabel('Tournament', size=16)
ax.set_xlabel('Number of tournament', size=16)
ax.set_title("TOP 10 TYPE OF MATCH TOURNAMENTS", fontsize=18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-dd383b1ab2cd> in <module>
# ----> 1 tournament = matches['tournament'].value_counts()
#       2 tournament = tournament[:10]
#       3
#       4 plt.figure(figsize = (15,10))
#       5 sns.set_style("whitegrid")
#
# NameError: name 'matches' is not defined
