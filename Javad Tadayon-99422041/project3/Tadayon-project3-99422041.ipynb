# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv('mobile.csv')
data_set.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
data_set.shape
# Out:
# (2000, 21)

# %%
X = data_set.drop('price_range', axis=1)
y = data_set['price_range']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn import svm
svm_clf = svm.SVC(kernel = 'linear')
svm_clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[145   0   0   0]
#  [  4 152   1   0]
#  [  0   5 152   1]
#  [  0   0   4 136]]

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.975

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.975

# %%
svm_clf = svm.SVC(kernel = 'poly', degree=3)
svm_clf.fit(X_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[145   0   0   0]
#  [  6 148   3   0]
#  [  0   6 150   2]
#  [  0   0   6 134]]

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.9616666666666667

# %%
svm_clf = svm.SVC(kernel = 'poly', degree=5)
svm_clf.fit(X_train, y_train)
# Out:
# SVC(degree=5, kernel='poly')

# %%
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[145   0   0   0]
#  [ 10 144   3   0]
#  [  0   5 152   1]
#  [  0   0   5 135]]

# %%
svm_clf = svm.SVC(C=0.5)
svm_clf.fit(X_train, y_train)
# Out:
# SVC(C=0.5)

# %%
svm_clf = svm.SVC(C=5)
svm_clf.fit(X_train, y_train)
# Out:
# SVC(C=5)

# %%
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[142   3   0   0]
#  [  3 151   3   0]
#  [  0   7 151   0]
#  [  0   0   5 135]]

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.965

# %%
svm_clf = svm.SVC(C=10)
svm_clf.fit(X_train, y_train)
# Out:
# SVC(C=10)

# %%
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[140   5   0   0]
#  [  3 151   3   0]
#  [  0   4 153   1]
#  [  0   0   4 136]]

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.9666666666666667

# %%
print(data_set['battery_power'].min())
print(data_set['battery_power'].max())
# Out:
# 501
# 1998

# %%
labels_3 = [0, 1, 2]
data_set['battery'] = pd.qcut(data_set['battery_power'], q=[0, 0.4, 0.7, 1], labels=labels_3)

# %%
data_set.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %%
X = data_set.drop(['price_range', 'battery_power'], axis=1)
y = data_set['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
svm_clf = svm.SVC()
svm_clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[124  21   0   0]
#  [ 18 103  27   0]
#  [  0  21 101  21]
#  [  0   0  23 141]]

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.7816666666666666

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_set1 = pd.DataFrame()
  

data_set1['four_g']= le.fit_transform(data_set['four_g'])
data_set1['battery_power']=le.fit_transform(data_set['battery_power'])
data_set1['blue']= le.fit_transform(data_set['blue'])
data_set1['wifi']= le.fit_transform(data_set['wifi'])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder()

columnTransformer = ColumnTransformer([('encoder',
                                        OneHotEncoder(),
                                        [0])],
                                      remainder='passthrough')

# %%
data_set1.head(10)
# Out:
#    four_g  battery_power  blue  wifi
# 0       0            255     0     1
# 1       1            382     1     0
# 2       1             48     1     0
# 3       0             88     1     0
# 4       1            954     1     0
# 5       0            986     0     0
# 6       1            954     0     1
# 7       0           1056     0     1
# 8       0            686     1     0
# 9       1              7     1     0

# %%
data_set1 = np.array(columnTransformer.fit_transform(data_set1), dtype = np.str)

# %%
df_encode = data_set

# %%
pd.concat([df_encode, pd.DataFrame(data_set1)], axis=1)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               255     0          2.2         0   1       0           7
# 1               382     1          0.5         1   0       1          53
# 2                48     1          0.5         1   2       1          41
# 3                88     1          2.5         0   0       0          10
# 4               954     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            216     1          0.5         1   0       1           2
# 1996           1064     1          2.6         1   0       0          39
# 1997           1027     0          0.9         1   1       1          36
# 1998            732     0          0.9         0   4       1          46
# 1999              8     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  three_g  touch_screen  wifi  \
# ...

# %%
df_encode = pd.concat([df_encode, pd.DataFrame(data_set1)], axis=1)

# %%
df_encode
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               255     0          2.2         0   1       0           7
# 1               382     1          0.5         1   0       1          53
# 2                48     1          0.5         1   2       1          41
# 3                88     1          2.5         0   0       0          10
# 4               954     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            216     1          0.5         1   0       1           2
# 1996           1064     1          2.6         1   0       0          39
# 1997           1027     0          0.9         1   1       1          36
# 1998            732     0          0.9         0   4       1          46
# 1999              8     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  three_g  touch_screen  wifi  \
# ...

# %%
X = df_encode.drop(['price_range', 'battery', 'blue', 'dual_sim', 'four_g', 'three_g', 'wifi'], axis=1)
y = df_encode['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[149   0   0   0]
#  [145   0   0   0]
#  [125  36   0   0]
#  [ 11 134   0   0]]

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.24833333333333332

# %%
data_set.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            255     0          2.2         0   1       0           7    0.6
# 1            382     1          0.5         1   0       1          53    0.7
# 2             48     1          0.5         1   2       1          41    0.9
# 3             88     1          2.5         0   0       0          10    0.8
# 4            954     1          1.2         0  13       1          44    0.6
# 5            986     0          0.5         1   3       0          22    0.7
# 6            954     0          1.7         0   4       1          10    0.8
# 7           1056     0          0.5         1   0       0          24    0.8
# 8            686     1          0.5         0   0       0          53    0.7
# 9              7     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %%
import seaborn as sns
sns.distplot(data_set['clock_speed'])
fig = plt.figure()
# Out:
# F:\yilan\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_set_log = data_set

# %%
data_set_log['clock_speed'] = np.log2(data_set['clock_speed'])

# %%
sns.distplot(data_set['battery_power'])
fig = plt.figure()
# Out:
# F:\yilan\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_set_log['battery_power'] = np.log2(data_set['battery_power'])
# Out:
# F:\yilan\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.distplot(data_set['m_dep'])
fig = plt.figure()
# Out:
# F:\yilan\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_set_log['m_dep'] = np.log2(data_set['m_dep'])

# %%
sns.distplot(data_set['talk_time'])
fig = plt.figure()
# Out:
# F:\yilan\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_set_log['talk_time'] = np.log2(data_set['talk_time'])

# %%
data_set_log.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       7.994353     0     1.137504         0   1       0           7
# 1       8.577429     1    -1.000000         1   0       1          53
# 2       5.584963     1    -1.000000         1   2       1          41
# 3       6.459432     1     1.321928         0   0       0          10
# 4       9.897845     1     0.263034         0  13       1          44
# 5       9.945444     0    -1.000000         1   3       0          22
# 6       9.897845     0     0.765535         0   4       1          10
# 7      10.044394     0    -1.000000         1   0       0          24
# 8       9.422065     1    -1.000000         0   0       0          53
# 9       2.807355     1    -0.736966         1   2       1           9
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# 0 -0.736966        188        2  ...       756  2549     9     7   4.247928
# ...

# %%
X = data_set_log.drop(['price_range', 'battery'], axis=1)
y = data_set_log['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.25833333333333336

# %%
data_set_area=data_set

# %%
data_set_area['area'] = data_set['px_height']*data_set['px_width']
data_set_area.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       7.994353     0     1.137504         0   1       0           7
# 1       8.577429     1    -1.000000         1   0       1          53
# 2       5.584963     1    -1.000000         1   2       1          41
# 3       6.459432     1     1.321928         0   0       0          10
# 4       9.897845     1     0.263034         0  13       1          44
#
#       m_dep  mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# 0 -0.736966        188        2  ...  2549     9     7   4.247928        0
# 1 -0.514573        136        3  ...  2631    17     3   2.807355        1
# 2 -0.152003        145        5  ...  2603    11     2   3.169925        1
# 3 -0.321928        131        6  ...  2769    16     8   3.459432        1
# 4 -0.736966        141        2  ...  1411     8     2   3.906891        1
#
#    touch_screen  wifi  price_range  battery     area
# ...

# %%
X = data_set_area.drop(['price_range', 'battery'], axis=1)
y = data_set_area['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
data_set_all = df_encode

# %%
data_set_all['area'] = data_set_area['area']

# %%
data_set_all['talk_time'] = data_set_log['talk_time']
data_set_all['m_dep'] = data_set_log['m_dep']
data_set_all['clock_speed'] = data_set_log['clock_speed']

# %%
data_set_all.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0            255     0     1.137504         0   1       0           7
# 1            382     1    -1.000000         1   0       1          53
# 2             48     1    -1.000000         1   2       1          41
# 3             88     1     1.321928         0   0       0          10
# 4            954     1     0.263034         0  13       1          44
# 5            986     0    -1.000000         1   3       0          22
# 6            954     0     0.765535         0   4       1          10
# 7           1056     0    -1.000000         1   0       0          24
# 8            686     1    -1.000000         0   0       0          53
# 9              7     1    -0.736966         1   2       1           9
#
#       m_dep  mobile_wt  n_cores  ...  touch_screen  wifi  price_range  \
# 0 -0.736966        188        2  ...             0     1            1
# ...

# %%
X = data_set_all.drop(['price_range', 'battery_power'], axis=1)
y = data_set_all['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
svm_clf = svm.SVC()
svm_clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_clf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[107  10   0  24]
#  [ 96   7   0  56]
#  [ 91   6   0  44]
#  [ 84   8   0  67]]

# %%
sva =accuracy_score(y_test,y_pred)
print('accuracy score = ',accuracy_score(y_test,y_pred))
# Out:
# accuracy score =  0.3016666666666667
